# %%
import pandas as pd

path = "/mnt/data/results_associativity.csv"
df = pd.read_csv(path)

# basic high-level factor sensitivity: mean result grouped by each factor individually
summary = {}
for col in ["dtype","dist","seed"]:
    summary[col] = df.groupby(col)["result"].mean().sort_values()

df.head(), summary
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 import pandas as pd
#       3 path = "/mnt/data/results_associativity.csv"
#       4 df = pd.read_csv(path)
#
# ModuleNotFoundError: No module named 'pandas'
